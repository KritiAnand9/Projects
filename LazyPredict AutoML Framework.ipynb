# %%
import sys
# !{sys.executable} -m pip install lazypredict
# Out:
# Collecting lazypredict
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\acer\\anaconda3\\Lib\\site-packages\\~cipy\\cluster\\_hierarchy.cp38-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#   Using cached lazypredict-0.2.9-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: six==1.15.0 in c:\users\acer\anaconda3\lib\site-packages (from lazypredict) (1.15.0)
# Collecting joblib==1.0.0
#   Using cached joblib-1.0.0-py3-none-any.whl (302 kB)
# Collecting lightgbm==2.3.1
#   Using cached lightgbm-2.3.1-py2.py3-none-win_amd64.whl (544 kB)
# Collecting pytest==5.4.3
#   Using cached pytest-5.4.3-py3-none-any.whl (248 kB)
# Collecting pandas==1.0.5
#   Using cached pandas-1.0.5-cp38-cp38-win_amd64.whl (8.9 MB)
# Collecting scipy==1.5.4
#   Using cached scipy-1.5.4-cp38-cp38-win_amd64.whl (31.4 MB)
# Requirement already satisfied: numpy==1.19.1 in c:\users\acer\anaconda3\lib\site-packages (from lazypredict) (1.19.1)
# Collecting scikit-learn==0.23.1
#   Using cached scikit_learn-0.23.1-cp38-cp38-win_amd64.whl (6.8 MB)
# Collecting tqdm==4.56.0
#   Using cached tqdm-4.56.0-py2.py3-none-any.whl (72 kB)
# Collecting PyYAML==5.3.1
#   Using cached PyYAML-5.3.1-cp38-cp38-win_amd64.whl (219 kB)
# Collecting xgboost==1.1.1
#   Using cached xgboost-1.1.1-py3-none-win_amd64.whl (54.4 MB)
# Requirement already satisfied: click==7.1.2 in c:\users\acer\anaconda3\lib\site-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\acer\anaconda3\lib\site-packages (from pandas==1.0.5->lazypredict) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\acer\anaconda3\lib\site-packages (from pandas==1.0.5->lazypredict) (2021.1)
# Requirement already satisfied: pluggy<1.0,>=0.12 in c:\users\acer\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.13.1)
# Requirement already satisfied: colorama in c:\users\acer\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.4.4)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\acer\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (20.3.0)
# Requirement already satisfied: wcwidth in c:\users\acer\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.2.5)
# Requirement already satisfied: packaging in c:\users\acer\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (20.9)
# Requirement already satisfied: more-itertools>=4.0.0 in c:\users\acer\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (8.7.0)
# Requirement already satisfied: py>=1.5.0 in c:\users\acer\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (1.10.0)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\acer\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\acer\anaconda3\lib\site-packages (from scikit-learn==0.23.1->lazypredict) (2.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\acer\anaconda3\lib\site-packages (from packaging->pytest==5.4.3->lazypredict) (2.4.7)
# Installing collected packages: scipy, joblib, scikit-learn, xgboost, tqdm, PyYAML, pytest, pandas, lightgbm, lazypredict
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.6.2
#     Uninstalling scipy-1.6.2:
#       Successfully uninstalled scipy-1.6.2

# %%
import lazypredict

# %%
from lazypredict.Supervised import LazyClassifier
# Out:
# C:\Users\acer\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from sklearn.datasets import load_breast_cancer

# %%
from sklearn.model_selection import train_test_split

# %%
data = load_breast_cancer()

# %%
X = data.data
y= data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.30,random_state =123)

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 13.41it/s]

# %%
print(models)
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LogisticRegression                 0.99               0.99     0.99      0.99
# SGDClassifier                      0.99               0.99     0.99      0.99
# LinearSVC                          0.99               0.99     0.99      0.99
# Perceptron                         0.99               0.99     0.99      0.99
# SVC                                0.98               0.98     0.98      0.98
# RandomForestClassifier             0.98               0.98     0.98      0.98
# ExtraTreesClassifier               0.98               0.98     0.98      0.98
# RidgeClassifier                    0.98               0.98     0.98      0.98
# QuadraticDiscriminantAnalysis      0.98               0.98     0.98      0.98
# AdaBoostClassifier                 0.98               0.98     0.98      0.98
# KNeighborsClassifier               0.98               0.97     0.97      0.98
# LinearDiscriminantAnalysis         0.98               0.97     0.97      0.98
# CalibratedClassifierCV             0.98               0.97     0.97      0.98
# LGBMClassifier                     0.97               0.97     0.97      0.97
# XGBClassifier                      0.97               0.97     0.97      0.97
# BernoulliNB                        0.96               0.96     0.96      0.96
# RidgeClassifierCV                  0.97               0.96     0.96      0.97
# PassiveAggressiveClassifier        0.96               0.96     0.96      0.96
# DecisionTreeClassifier             0.96               0.96     0.96      0.96
# LabelPropagation                   0.96               0.96     0.96      0.96
# LabelSpreading                     0.96               0.96     0.96      0.96
# NuSVC                              0.96               0.96     0.96      0.96
# NearestCentroid                    0.96               0.96     0.96      0.96
# BaggingClassifier                  0.95               0.95     0.95      0.95
# ExtraTreeClassifier                0.96               0.95     0.95      0.96
# GaussianNB                         0.96               0.95     0.95      0.96
# DummyClassifier                    0.57               0.53     0.53      0.56
#
#                                Time Taken
# Model
# LogisticRegression                   0.05
# SGDClassifier                        0.01
# LinearSVC                            0.02
# Perceptron                           0.02
# SVC                                  0.02
# RandomForestClassifier               0.35
# ExtraTreesClassifier                 0.22
# RidgeClassifier                      0.02
# QuadraticDiscriminantAnalysis        0.15
# AdaBoostClassifier                   0.36
# KNeighborsClassifier                 0.03
# LinearDiscriminantAnalysis           0.02
# CalibratedClassifierCV               0.06
# LGBMClassifier                       0.21
# XGBClassifier                        0.10
# BernoulliNB                          0.07
# RidgeClassifierCV                    0.02
# PassiveAggressiveClassifier          0.01
# DecisionTreeClassifier               0.03
# LabelPropagation                     0.07
# LabelSpreading                       0.04
# NuSVC                                0.03
# NearestCentroid                      0.02
# BaggingClassifier                    0.11
# ExtraTreeClassifier                  0.02
# GaussianNB                           0.02
# DummyClassifier                      0.03

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LogisticRegression                 0.99               0.99     0.99      0.99
# SGDClassifier                      0.99               0.99     0.99      0.99
# LinearSVC                          0.99               0.99     0.99      0.99
# Perceptron                         0.99               0.99     0.99      0.99
# SVC                                0.98               0.98     0.98      0.98
# RandomForestClassifier             0.98               0.98     0.98      0.98
# ExtraTreesClassifier               0.98               0.98     0.98      0.98
# RidgeClassifier                    0.98               0.98     0.98      0.98
# QuadraticDiscriminantAnalysis      0.98               0.98     0.98      0.98
# AdaBoostClassifier                 0.98               0.98     0.98      0.98
# KNeighborsClassifier               0.98               0.97     0.97      0.98
# LinearDiscriminantAnalysis         0.98               0.97     0.97      0.98
# CalibratedClassifierCV             0.98               0.97     0.97      0.98
# LGBMClassifier                     0.97               0.97     0.97      0.97
# XGBClassifier                      0.97               0.97     0.97      0.97
# BernoulliNB                        0.96               0.96     0.96      0.96
# RidgeClassifierCV                  0.97               0.96     0.96      0.97
# PassiveAggressiveClassifier        0.96               0.96     0.96      0.96
# DecisionTreeClassifier             0.96               0.96     0.96      0.96
# LabelPropagation                   0.96               0.96     0.96      0.96
# LabelSpreading                     0.96               0.96     0.96      0.96
# NuSVC                              0.96               0.96     0.96      0.96
# NearestCentroid                    0.96               0.96     0.96      0.96
# BaggingClassifier                  0.95               0.95     0.95      0.95
# ExtraTreeClassifier                0.96               0.95     0.95      0.96
# GaussianNB                         0.96               0.95     0.95      0.96
# DummyClassifier                    0.57               0.53     0.53      0.56
#
#                                Time Taken
# Model
# LogisticRegression                   0.05
# SGDClassifier                        0.01
# LinearSVC                            0.02
# Perceptron                           0.02
# SVC                                  0.02
# RandomForestClassifier               0.35
# ExtraTreesClassifier                 0.22
# RidgeClassifier                      0.02
# QuadraticDiscriminantAnalysis        0.15
# AdaBoostClassifier                   0.36
# KNeighborsClassifier                 0.03
# LinearDiscriminantAnalysis           0.02
# CalibratedClassifierCV               0.06
# LGBMClassifier                       0.21
# XGBClassifier                        0.10
# BernoulliNB                          0.07
# RidgeClassifierCV                    0.02
# PassiveAggressiveClassifier          0.01
# DecisionTreeClassifier               0.03
# LabelPropagation                     0.07
# LabelSpreading                       0.04
# NuSVC                                0.03
# NearestCentroid                      0.02
# BaggingClassifier                    0.11
# ExtraTreeClassifier                  0.02
# GaussianNB                           0.02
# DummyClassifier                      0.03

# %%
from lazypredict.Supervised import LazyRegressor

# %%
from sklearn import datasets

# %%
from sklearn.utils import shuffle

# %%
import numpy as np

# %%
boston = datasets.load_boston()

# %%
X, y = shuffle(boston.data, boston.target, random_state=13)

# %%
offset = int(X.shape[0] * 0.9)

# %%
X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

# %%
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████| 42/42 [00:04<00:00,  8.96it/s]

# %%
print(models)
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# SVR                                          0.83       0.88  2.62        0.02
# BaggingRegressor                             0.83       0.88  2.63        0.09
# NuSVR                                        0.82       0.86  2.76        0.02
# RandomForestRegressor                        0.81       0.86  2.79        0.47
# XGBRegressor                                 0.81       0.86  2.79        0.14
# GradientBoostingRegressor                    0.81       0.86  2.84        0.19
# ExtraTreesRegressor                          0.79       0.84  2.98        0.30
# HistGradientBoostingRegressor                0.77       0.83  3.06        1.22
# AdaBoostRegressor                            0.77       0.83  3.06        0.21
# PoissonRegressor                             0.77       0.83  3.11        0.02
# LGBMRegressor                                0.77       0.83  3.11        0.14
# KNeighborsRegressor                          0.77       0.83  3.12        0.02
# DecisionTreeRegressor                        0.65       0.74  3.79        0.02
# MLPRegressor                                 0.65       0.74  3.80        1.01
# HuberRegressor                               0.64       0.74  3.84        0.08
# GammaRegressor                               0.64       0.73  3.88        0.01
# LinearSVR                                    0.62       0.72  3.96        0.02
# RidgeCV                                      0.62       0.72  3.97        0.00
# BayesianRidge                                0.62       0.72  3.97        0.01
# Ridge                                        0.62       0.72  3.97        0.02
# TransformedTargetRegressor                   0.62       0.72  3.97        0.02
# LinearRegression                             0.62       0.72  3.97        0.02
# ElasticNetCV                                 0.62       0.72  3.98        0.10
# LassoCV                                      0.62       0.72  3.98        0.11
# LassoLarsIC                                  0.62       0.72  3.98        0.01
# LassoLarsCV                                  0.62       0.72  3.98        0.03
# Lars                                         0.61       0.72  3.99        0.01
# LarsCV                                       0.61       0.71  4.02        0.04
# SGDRegressor                                 0.60       0.70  4.07        0.01
# TweedieRegressor                             0.59       0.70  4.12        0.01
# GeneralizedLinearRegressor                   0.59       0.70  4.12        0.01
# ElasticNet                                   0.58       0.69  4.16        0.03
# Lasso                                        0.54       0.66  4.35        0.02
# RANSACRegressor                              0.53       0.65  4.41        0.08
# OrthogonalMatchingPursuitCV                  0.45       0.59  4.78        0.02
# PassiveAggressiveRegressor                   0.37       0.54  5.09        0.01
# GaussianProcessRegressor                     0.23       0.43  5.65        0.05
# OrthogonalMatchingPursuit                    0.16       0.38  5.89        0.01
# ExtraTreeRegressor                           0.08       0.32  6.17        0.01
# DummyRegressor                              -0.38      -0.02  7.56        0.00
# LassoLars                                   -0.38      -0.02  7.56        0.01
# KernelRidge                                -11.50      -8.25 22.74        0.02

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# SVR                                          0.83       0.88  2.62        0.02
# BaggingRegressor                             0.83       0.88  2.63        0.09
# NuSVR                                        0.82       0.86  2.76        0.02
# RandomForestRegressor                        0.81       0.86  2.79        0.47
# XGBRegressor                                 0.81       0.86  2.79        0.14
# GradientBoostingRegressor                    0.81       0.86  2.84        0.19
# ExtraTreesRegressor                          0.79       0.84  2.98        0.30
# HistGradientBoostingRegressor                0.77       0.83  3.06        1.22
# AdaBoostRegressor                            0.77       0.83  3.06        0.21
# PoissonRegressor                             0.77       0.83  3.11        0.02
# LGBMRegressor                                0.77       0.83  3.11        0.14
# KNeighborsRegressor                          0.77       0.83  3.12        0.02
# DecisionTreeRegressor                        0.65       0.74  3.79        0.02
# MLPRegressor                                 0.65       0.74  3.80        1.01
# HuberRegressor                               0.64       0.74  3.84        0.08
# GammaRegressor                               0.64       0.73  3.88        0.01
# LinearSVR                                    0.62       0.72  3.96        0.02
# RidgeCV                                      0.62       0.72  3.97        0.00
# BayesianRidge                                0.62       0.72  3.97        0.01
# Ridge                                        0.62       0.72  3.97        0.02
# TransformedTargetRegressor                   0.62       0.72  3.97        0.02
# LinearRegression                             0.62       0.72  3.97        0.02
# ElasticNetCV                                 0.62       0.72  3.98        0.10
# LassoCV                                      0.62       0.72  3.98        0.11
# LassoLarsIC                                  0.62       0.72  3.98        0.01
# LassoLarsCV                                  0.62       0.72  3.98        0.03
# Lars                                         0.61       0.72  3.99        0.01
# LarsCV                                       0.61       0.71  4.02        0.04
# SGDRegressor                                 0.60       0.70  4.07        0.01
# TweedieRegressor                             0.59       0.70  4.12        0.01
# GeneralizedLinearRegressor                   0.59       0.70  4.12        0.01
# ElasticNet                                   0.58       0.69  4.16        0.03
# Lasso                                        0.54       0.66  4.35        0.02
# RANSACRegressor                              0.53       0.65  4.41        0.08
# OrthogonalMatchingPursuitCV                  0.45       0.59  4.78        0.02
# PassiveAggressiveRegressor                   0.37       0.54  5.09        0.01
# GaussianProcessRegressor                     0.23       0.43  5.65        0.05
# OrthogonalMatchingPursuit                    0.16       0.38  5.89        0.01
# ExtraTreeRegressor                           0.08       0.32  6.17        0.01
# DummyRegressor                              -0.38      -0.02  7.56        0.00
# LassoLars                                   -0.38      -0.02  7.56        0.01
# KernelRidge                                -11.50      -8.25 22.74        0.02
