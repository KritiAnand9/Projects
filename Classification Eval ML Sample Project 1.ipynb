# %%
import evalml

# %%
X, y = evalml.demos.load_breast_cancer()
# Out:
#          Number of Features
# Numeric                  30
#
# Number of training examples: 569
# Targets
# benign       62.74%
# malignant    37.26%
# Name: target, dtype: object

# %%
X_train, X_test, y_train, y_test = evalml.preprocessing.split_data(X, y, problem_type='binary')

# %%
X_train.head()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 381        11.04         14.93           70.67      372.7          0.07987
# 144        10.75         14.97           68.26      355.3          0.07793
# 136        11.71         16.67           74.72      423.6          0.10510
# 116         8.95         15.76           58.74      245.2          0.09462
# 567        20.60         29.33          140.10     1265.0          0.11780
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 381           0.07079         0.03546             0.020740         0.2003
# 144           0.05139         0.02251             0.007875         0.1399
# 136           0.06095         0.03592             0.026000         0.1339
# 116           0.12430         0.09263             0.023080         0.1305
# 567           0.27700         0.35140             0.152000         0.2397
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 381                 0.06246  ...        12.090          20.83
# 144                 0.05688  ...        11.950          20.72
# 136                 0.05945  ...        13.330          25.48
# 116                 0.07163  ...         9.414          17.07
# 567                 0.07016  ...        25.740          39.42
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 381            79.73       447.1            0.1095             0.1982
# 144            77.79       441.2            0.1076             0.1223
# 136            86.16       546.7            0.1271             0.1028
# 116            63.34       270.0            0.1179             0.1879
# 567           184.60      1821.0            0.1650             0.8681
#
#      worst concavity  worst concave points  worst symmetry  \
# 381          0.15530               0.06754          0.3202
# 144          0.09755               0.03413          0.2300
# 136          0.10460               0.06968          0.1712
# 116          0.15440               0.03846          0.1652
# 567          0.93870               0.26500          0.4087
#
#      worst fractal dimension
# 381                  0.07287
# 144                  0.06769
# 136                  0.07343
# 116                  0.07722
# 567                  0.12400
#
# [5 rows x 30 columns]

# %%
evalml.problem_types.ProblemTypes.all_problem_types
# Out:
# [<ProblemTypes.BINARY: 'binary'>,
#  <ProblemTypes.MULTICLASS: 'multiclass'>,
#  <ProblemTypes.REGRESSION: 'regression'>,
#  <ProblemTypes.TIME_SERIES_REGRESSION: 'time series regression'>,
#  <ProblemTypes.TIME_SERIES_BINARY: 'time series binary'>,
#  <ProblemTypes.TIME_SERIES_MULTICLASS: 'time series multiclass'>]

# %%
from evalml.automl import AutoMLSearch
automl = AutoMLSearch(X_train=X_train, y_train=y_train, problem_type='binary')
automl.search()
# Out:
# Using default limit of max_batches=1.
#
# Generating pipelines to search over...
# 8 pipelines ready for search.
#
# *****************************
# * Beginning pipeline search *
# *****************************
#
# Optimizing for Log Loss Binary.
# Lower score is better.
#
# Using SequentialEngine to train and score pipelines.
# Searching up to 1 batches for a total of 9 pipelines.
# Allowed model families: decision_tree, linear_model, catboost, xgboost, extra_trees, random_forest, lightgbm
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'name': 'Best Score',
#               'type'…
# Evaluating Baseline Pipeline: Mode Baseline Binary Classification Pipeline
# Mode Baseline Binary Classification Pipeline:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 12.904
#
# *****************************
# * Evaluating Batch Number 1 *
# *****************************
#
# Elastic Net Classifier w/ Imputer + Standard Scaler:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 0.081
# 	High coefficient of variation (cv >= 0.2) within cross validation scores.
# 	Elastic Net Classifier w/ Imputer + Standard Scaler may not perform as estimated on unseen data.
# Decision Tree Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 3.340
# Random Forest Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 0.123
# LightGBM Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 0.139
# 	High coefficient of variation (cv >= 0.2) within cross validation scores.
# 	LightGBM Classifier w/ Imputer may not perform as estimated on unseen data.
# Logistic Regression Classifier w/ Imputer + Standard Scaler:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 0.086
# 	High coefficient of variation (cv >= 0.2) within cross validation scores.
# 	Logistic Regression Classifier w/ Imputer + Standard Scaler may not perform as estimated on unseen data.
# XGBoost Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 0.113
# 	High coefficient of variation (cv >= 0.2) within cross validation scores.
# 	XGBoost Classifier w/ Imputer may not perform as estimated on unseen data.
# Extra Trees Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 0.134
# CatBoost Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 0.399
#
# Search finished after 00:26
# Best pipeline: Elastic Net Classifier w/ Imputer + Standard Scaler
# Best pipeline Log Loss Binary: 0.081418

# %%
automl.rankings
# Out:
#    id                                      pipeline_name  search_order  \
# 0   1  Elastic Net Classifier w/ Imputer + Standard S...             1
# 1   5  Logistic Regression Classifier w/ Imputer + St...             5
# 2   6                      XGBoost Classifier w/ Imputer             6
# 3   3                Random Forest Classifier w/ Imputer             3
# 4   7                  Extra Trees Classifier w/ Imputer             7
# 5   4                     LightGBM Classifier w/ Imputer             4
# 6   8                     CatBoost Classifier w/ Imputer             8
# 7   2                Decision Tree Classifier w/ Imputer             2
# 8   0       Mode Baseline Binary Classification Pipeline             0
#
#    mean_cv_score  standard_deviation_cv_score  validation_score  \
# 0       0.081418                     0.021666          0.056533
# 1       0.086498                     0.024840          0.058400
# 2       0.113207                     0.035053          0.075787
# 3       0.122844                     0.018427          0.106077
# 4       0.134290                     0.023928          0.106956
# 5       0.139108                     0.056151          0.091426
# 6       0.398523                     0.014553          0.381786
# 7       3.340255                     0.138178          3.181235
# 8      12.904388                     0.082537         12.952041
#
#    percent_better_than_baseline  high_variance_cv  \
# 0                     99.369066              True
# 1                     99.329702              True
# 2                     99.122726              True
# 3                     99.048042             False
# 4                     98.959343             False
# 5                     98.922009              True
# 6                     96.911724             False
# 7                     74.115354             False
# 8                      0.000000             False
#
#                                           parameters
# 0  {'Imputer': {'categorical_impute_strategy': 'm...
# 1  {'Imputer': {'categorical_impute_strategy': 'm...
# 2  {'Imputer': {'categorical_impute_strategy': 'm...
# 3  {'Imputer': {'categorical_impute_strategy': 'm...
# 4  {'Imputer': {'categorical_impute_strategy': 'm...
# 5  {'Imputer': {'categorical_impute_strategy': 'm...
# 6  {'Imputer': {'categorical_impute_strategy': 'm...
# 7  {'Imputer': {'categorical_impute_strategy': 'm...
# 8      {'Baseline Classifier': {'strategy': 'mode'}}

# %%
automl.best_pipeline
# Out:
# pipeline = BinaryClassificationPipeline(component_graph={'Imputer': ['Imputer'], 'Standard Scaler': ['Standard Scaler', 'Imputer.x'], 'Elastic Net Classifier': ['Elastic Net Classifier', 'Standard Scaler.x']}, parameters={'Imputer':{'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'Elastic Net Classifier':{'penalty': 'elasticnet', 'C': 1.0, 'l1_ratio': 0.15, 'n_jobs': -1, 'multi_class': 'auto', 'solver': 'saga'}}, random_seed=0)

# %%
best_pipeline=automl.best_pipeline

# %%
automl.describe_pipeline(automl.rankings.iloc[0]["id"])
# Out:
# *******************************************************
# * Elastic Net Classifier w/ Imputer + Standard Scaler *
# *******************************************************
#
# Problem Type: binary
# Model Family: Linear
#
# Pipeline Steps
# ==============
# 1. Imputer
# 	 * categorical_impute_strategy : most_frequent
# 	 * numeric_impute_strategy : mean
# 	 * categorical_fill_value : None
# 	 * numeric_fill_value : None
# 2. Standard Scaler
# 3. Elastic Net Classifier
# 	 * penalty : elasticnet
# 	 * C : 1.0
# 	 * l1_ratio : 0.15
# 	 * n_jobs : -1
# 	 * multi_class : auto
# 	 * solver : saga
#
# Training
# ========
# Training for binary problems.
# Total training time (including CV): 2.4 seconds
#
# Cross Validation
# ----------------
#              Log Loss Binary  MCC Binary   AUC  Precision    F1  Balanced Accuracy Binary  Accuracy Binary # Training # Validation
# 0                      0.057       0.958 0.997      0.966 0.974                     0.981            0.980        303          152
# 1                      0.092       0.958 0.995      0.966 0.974                     0.981            0.980        303          152
# 2                      0.096       0.943 0.993      0.981 0.964                     0.968            0.974        304          151
# mean                   0.081       0.953 0.995      0.971 0.970                     0.976            0.978          -            -
# std                    0.022       0.009 0.002      0.009 0.006                     0.007            0.004          -            -
# coef of var            0.266       0.009 0.002      0.009 0.006                     0.008            0.004          -            -

# %%
best_pipeline.score(X_test, y_test, objectives=["auc","f1","Precision","Recall"])
# Out:
# OrderedDict([('AUC', 0.9927248677248677),
#              ('F1', 0.962962962962963),
#              ('Precision', 1.0),
#              ('Recall', 0.9285714285714286)])

# %%
automl_auc = AutoMLSearch(X_train=X_train, y_train=y_train,
                          problem_type='binary',
                          objective='auc',
                          additional_objectives=['f1', 'precision'],
                          max_batches=1,
                          optimize_thresholds=True)

automl_auc.search()
# Out:
# Generating pipelines to search over...
# 8 pipelines ready for search.
#
# *****************************
# * Beginning pipeline search *
# *****************************
#
# Optimizing for AUC.
# Greater score is better.
#
# Using SequentialEngine to train and score pipelines.
# Searching up to 1 batches for a total of 9 pipelines.
# Allowed model families: decision_tree, linear_model, catboost, xgboost, extra_trees, random_forest, lightgbm
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'name': 'Best Score',
#               'type'…
# Evaluating Baseline Pipeline: Mode Baseline Binary Classification Pipeline
# Mode Baseline Binary Classification Pipeline:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.500
#
# *****************************
# * Evaluating Batch Number 1 *
# *****************************
#
# Elastic Net Classifier w/ Imputer + Standard Scaler:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.995
# Decision Tree Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.899
# Random Forest Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.992
# LightGBM Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.993
# Logistic Regression Classifier w/ Imputer + Standard Scaler:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.993
# XGBoost Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.991
# Extra Trees Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.994
# CatBoost Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.988
#
# Search finished after 00:23
# Best pipeline: Elastic Net Classifier w/ Imputer + Standard Scaler
# Best pipeline AUC: 0.995158

# %%
automl_auc.rankings
# Out:
#    id                                      pipeline_name  search_order  \
# 0   1  Elastic Net Classifier w/ Imputer + Standard S...             1
# 1   7                  Extra Trees Classifier w/ Imputer             7
# 2   5  Logistic Regression Classifier w/ Imputer + St...             5
# 3   4                     LightGBM Classifier w/ Imputer             4
# 4   3                Random Forest Classifier w/ Imputer             3
# 5   6                      XGBoost Classifier w/ Imputer             6
# 6   8                     CatBoost Classifier w/ Imputer             8
# 7   2                Decision Tree Classifier w/ Imputer             2
# 8   0       Mode Baseline Binary Classification Pipeline             0
#
#    mean_cv_score  standard_deviation_cv_score  validation_score  \
# 0       0.995158                     0.002010          0.997045
# 1       0.993597                     0.003806          0.996491
# 2       0.993310                     0.003531          0.997045
# 3       0.992788                     0.004551          0.996676
# 4       0.991616                     0.004007          0.992059
# 5       0.991439                     0.002779          0.994275
# 6       0.988404                     0.002658          0.990766
# 7       0.899102                     0.000878          0.898246
# 8       0.500000                     0.000000          0.500000
#
#    percent_better_than_baseline  high_variance_cv  \
# 0                     49.515785             False
# 1                     49.359693             False
# 2                     49.331003             False
# 3                     49.278789             False
# 4                     49.161610             False
# 5                     49.143912             False
# 6                     48.840412             False
# 7                     39.910192             False
# 8                      0.000000             False
#
#                                           parameters
# 0  {'Imputer': {'categorical_impute_strategy': 'm...
# 1  {'Imputer': {'categorical_impute_strategy': 'm...
# 2  {'Imputer': {'categorical_impute_strategy': 'm...
# 3  {'Imputer': {'categorical_impute_strategy': 'm...
# 4  {'Imputer': {'categorical_impute_strategy': 'm...
# 5  {'Imputer': {'categorical_impute_strategy': 'm...
# 6  {'Imputer': {'categorical_impute_strategy': 'm...
# 7  {'Imputer': {'categorical_impute_strategy': 'm...
# 8      {'Baseline Classifier': {'strategy': 'mode'}}

# %%
automl_auc.describe_pipeline(automl_auc.rankings.iloc[0]["id"])
# Out:
# *******************************************************
# * Elastic Net Classifier w/ Imputer + Standard Scaler *
# *******************************************************
#
# Problem Type: binary
# Model Family: Linear
#
# Pipeline Steps
# ==============
# 1. Imputer
# 	 * categorical_impute_strategy : most_frequent
# 	 * numeric_impute_strategy : mean
# 	 * categorical_fill_value : None
# 	 * numeric_fill_value : None
# 2. Standard Scaler
# 3. Elastic Net Classifier
# 	 * penalty : elasticnet
# 	 * C : 1.0
# 	 * l1_ratio : 0.15
# 	 * n_jobs : -1
# 	 * multi_class : auto
# 	 * solver : saga
#
# Training
# ========
# Training for binary problems.
# Total training time (including CV): 2.0 seconds
#
# Cross Validation
# ----------------
#               AUC    F1  Precision # Training # Validation
# 0           0.997 0.974      0.966        303          152
# 1           0.995 0.974      0.966        303          152
# 2           0.993 0.964      0.981        304          151
# mean        0.995 0.970      0.971          -            -
# std         0.002 0.006      0.009          -            -
# coef of var 0.002 0.006      0.009          -            -

# %%
best_pipeline_auc = automl_auc.best_pipeline

# %%
best_pipeline_auc.score(X_test, y_test,  objectives=["auc"])
# Out:
# OrderedDict([('AUC', 0.9927248677248677)])

# %%
best_pipeline.save("model.pkl")

# %%
check_model=automl.load('model.pkl')

# %%
check_model.predict_proba(X_test)
# Out:
#            benign  malignant
# 0    9.990303e-01   0.000970
# 1    9.722545e-01   0.027746
# 2    7.212180e-01   0.278782
# 3    9.886639e-01   0.011336
# 4    9.995264e-01   0.000474
# ..            ...        ...
# 109  9.983336e-01   0.001666
# 110  7.419928e-01   0.258007
# 111  9.999658e-01   0.000034
# 112  4.581885e-08   1.000000
# 113  9.998435e-01   0.000157
#
# [114 rows x 2 columns]
